# %%
pip config set global.index-url https://pypi.org/simple
# Out:
# Writing to C:\Users\86189\AppData\Roaming\pip\pip.ini
# Note: you may need to restart the kernel to use updated packages.

# %%
pip config set global.index-url https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Writing to C:\Users\86189\AppData\Roaming\pip\pip.ini
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import re

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\86189\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
lst_stopwords = nltk.corpus.stopwords.words("english")

# %%
#conda install d:\2021\multi_rake-0.0.2-pyhd8ed1ab_0.tar.bz2
#use anaconda3 powershell to run above command it successfully
# Out:
#   File "C:\Users\86189\AppData\Local\Temp/ipykernel_28824/1050401730.py", line 1
#     conda install d:\2021\multi_rake-0.0.2-pyhd8ed1ab_0.tar.bz2
#           ^
# SyntaxError: invalid syntax

# %%
#conda install d:\2021\pycld2-0.41-py38h12bbefe_0.tar.bz2
#use above to install pycld2
# Out:
#   File "C:\Users\86189\AppData\Local\Temp/ipykernel_13440/4278552286.py", line 1
#     conda install -c d:\2021\pycld2-0.41-py38h12bbefe_0.tar.bz2
#           ^
# SyntaxError: invalid syntax

# %%
#cp39 matches the python version in my jupyter
pip install d:\2021\pycld2-0.41-cp39-cp39-win_amd64.whl
# Out:
# Processing d:\2021\pycld2-0.41-cp39-cp39-win_amd64.whlNote: you may need to restart the kernel to use updated packages.
# ...

# %%
from multi_rake import Rake
rake = Rake()

# %%
'''
Preprocess a string.
:parameter
    :param text: string - name of column containing text
    :param lst_stopwords: list - list of stopwords to remove
    :param flg_stemm: bool - whether stemming is to be applied
    :param flg_lemm: bool - whether lemmitisation is to be applied
:return
    cleaned text
'''
def utils_preprocess_text(text, flg_stemm=False, flg_lemm=True, lst_stopwords=None):
    ## clean (convert to lowercase and remove punctuations and  characters and then strip)
    text = re.sub(r'[^\w\s\r\n]', '', str(text).lower().strip())
            
    ## Tokenize (convert from string to list)
    lst_text = text.split()    
    ## remove Stopwords
    if lst_stopwords is not None:
        lst_text = [word for word in lst_text if word not in 
                    lst_stopwords]
                
    ## Stemming (remove -ing, -ly, ...)
    if flg_stemm == True:
        ps = nltk.stem.porter.PorterStemmer()
        lst_text = [ps.stem(word) for word in lst_text]
                
    ## Lemmatisation (convert the word into root word)
    if flg_lemm == True:
        lem = nltk.stem.wordnet.WordNetLemmatizer()
        lst_text = [lem.lemmatize(word) for word in lst_text]
            
    ## back to string from list
    text = " ".join(lst_text)
    return text

# %%
col_list = ["description"]
type_dict = {"description":str}
df1 = pd.read_csv('d:/2021/欧盟碳足迹数据库-部分.csv',usecols=col_list,encoding='ISO-8859-1',dtype=type_dict)

# %%
df1["desc_clean"] = df1["description"].apply(lambda x: 
          utils_preprocess_text(x, flg_stemm=False, flg_lemm=True, 
          lst_stopwords=None))
df1.head()
# Out:
#   description desc_clean
# 0           -
# 1           -
# 2           -
# 3           -
# 4           -

# %%
description_kw = []
for desc in df1["desc_clean"]:
    keywords=rake.apply(desc)
    print(keywords[:5])
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('background data orginates', 8.0), ('background data', 5.0), ('stock allocation', 4.0), ('allocation ha', 4.0), ('agribalyse information', 4.0)]
# ...

# %%
text = df1["desc_clean"][900]
text
# Out:
# 'the dataset represents the manufacture of raw material for the paint industry it is based on the model created for the cepe raw material database version 3 european council of the paint printing ink and artist colour industry limited access which have been updated with pefcompliant background source based on ecoinvent 33 and processbased efcompliant lci datasets for energy and transport the inventory is based on literature and background source following general assumption for the paint industry biogenic carbon content 456 water content 0'

# %%
keywords=rake.apply(text)
print(keywords[:5])
# Out:
# [('paint printing ink', 8.5), ('paint industry', 4.5), ('dataset represents', 4.0), ('raw material', 4.0), ('model created', 4.0)]
